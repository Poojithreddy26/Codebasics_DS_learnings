# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("canada_per_capita_income.csv")
df.head()
df.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='object')

# %%
# %matplotlib inline
plt.xlabel("Year")
plt.ylabel("Per capita income(US$)")
plt.scatter(df.year,df["per capita income (US$)"],color='red',marker='+')
sns.regplot(data=df,x=df.year,y=df["per capita income (US$)"])
# Out:
# <Axes: xlabel='year', ylabel='per capita income (US$)'>

# %%
new_df = df.drop("per capita income (US$)",axis='columns')
new_df.head()
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
ln_reg = linear_model.LinearRegression()
ln_reg.fit(new_df,df["per capita income (US$)"])
# Out:
# LinearRegression()

# %%
ln_reg.predict([[2020]])
# Out:
# C:\Users\ntuse\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
ln_reg.coef_
# Out:
# array([828.46507522])

# %%
ln_reg.intercept_
# Out:
# -1632210.7578554575

# %%
828.46507522*2020+-1632210.7578554575 # y= mx+c where m = coef_ and c = intercept and x = 2020-here
# Out:
# 41288.694088942604
