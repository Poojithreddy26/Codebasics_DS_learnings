# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
# Note: you may need to restart the kernel to use updated packages.
#   Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ntuse\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (1.26.4)
# Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.8 MB 1.1 MB/s eta 0:00:35
#    ---------------------------------------- 0.2/38.8 MB 2.5 MB/s eta 0:00:16
#    ---------------------------------------- 0.4/38.8 MB 2.9 MB/s eta 0:00:14
#     --------------------------------------- 0.6/38.8 MB 3.3 MB/s eta 0:00:12
#     --------------------------------------- 0.8/38.8 MB 3.4 MB/s eta 0:00:12
#    - -------------------------------------- 1.0/38.8 MB 3.6 MB/s eta 0:00:11
#    - -------------------------------------- 1.2/38.8 MB 3.7 MB/s eta 0:00:11
#    - -------------------------------------- 1.4/38.8 MB 3.8 MB/s eta 0:00:10
#    - -------------------------------------- 1.6/38.8 MB 3.7 MB/s eta 0:00:10
#    - -------------------------------------- 1.9/38.8 MB 4.0 MB/s eta 0:00:10
#    -- ------------------------------------- 2.1/38.8 MB 3.9 MB/s eta 0:00:10
#    -- ------------------------------------- 2.3/38.8 MB 4.0 MB/s eta 0:00:10
#    -- ------------------------------------- 2.5/38.8 MB 4.1 MB/s eta 0:00:09
#    -- ------------------------------------- 2.8/38.8 MB 4.1 MB/s eta 0:00:09
#    --- ------------------------------------ 3.0/38.8 MB 4.2 MB/s eta 0:00:09
#    --- ------------------------------------ 3.2/38.8 MB 4.2 MB/s eta 0:00:09
#    --- ------------------------------------ 3.5/38.8 MB 4.2 MB/s eta 0:00:09
#    --- ------------------------------------ 3.7/38.8 MB 4.3 MB/s eta 0:00:09
#    ---- ----------------------------------- 3.9/38.8 MB 4.3 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.1/38.8 MB 4.3 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.4/38.8 MB 4.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.6/38.8 MB 4.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.8/38.8 MB 4.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.0/38.8 MB 4.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.2/38.8 MB 4.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.4/38.8 MB 4.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.7/38.8 MB 4.4 MB/s eta 0:00:08
#    ------ --------------------------------- 5.9/38.8 MB 4.4 MB/s eta 0:00:08
#    ------ --------------------------------- 6.1/38.8 MB 4.4 MB/s eta 0:00:08
#    ------ --------------------------------- 6.3/38.8 MB 4.5 MB/s eta 0:00:08
#    ------ --------------------------------- 6.6/38.8 MB 4.5 MB/s eta 0:00:08
#    ------- -------------------------------- 6.8/38.8 MB 4.4 MB/s eta 0:00:08
#    ------- -------------------------------- 7.0/38.8 MB 4.5 MB/s eta 0:00:08
#    ------- -------------------------------- 7.3/38.8 MB 4.5 MB/s eta 0:00:07
#    ------- -------------------------------- 7.5/38.8 MB 4.5 MB/s eta 0:00:07
#    ------- -------------------------------- 7.7/38.8 MB 4.5 MB/s eta 0:00:07
#    -------- ------------------------------- 7.8/38.8 MB 4.5 MB/s eta 0:00:07
#    -------- ------------------------------- 8.1/38.8 MB 4.5 MB/s eta 0:00:07
#    -------- ------------------------------- 8.3/38.8 MB 4.5 MB/s eta 0:00:07
#    -------- ------------------------------- 8.4/38.8 MB 4.5 MB/s eta 0:00:07
#    -------- ------------------------------- 8.6/38.8 MB 4.4 MB/s eta 0:00:07
#    --------- ------------------------------ 8.8/38.8 MB 4.4 MB/s eta 0:00:07
#    --------- ------------------------------ 9.0/38.8 MB 4.4 MB/s eta 0:00:07
#    --------- ------------------------------ 9.2/38.8 MB 4.4 MB/s eta 0:00:07
#    --------- ------------------------------ 9.4/38.8 MB 4.4 MB/s eta 0:00:07
#    --------- ------------------------------ 9.6/38.8 MB 4.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 9.8/38.8 MB 4.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 10.0/38.8 MB 4.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 10.2/38.8 MB 4.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 10.4/38.8 MB 4.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 10.5/38.8 MB 4.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 10.7/38.8 MB 4.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 10.9/38.8 MB 4.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 11.0/38.8 MB 4.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 11.2/38.8 MB 4.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 11.4/38.8 MB 4.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 11.6/38.8 MB 4.4 MB/s eta 0:00:07
#    ------------ --------------------------- 11.8/38.8 MB 4.3 MB/s eta 0:00:07
#    ------------ --------------------------- 12.0/38.8 MB 4.3 MB/s eta 0:00:07
#    ------------ --------------------------- 12.1/38.8 MB 4.3 MB/s eta 0:00:07
#    ------------ --------------------------- 12.3/38.8 MB 4.3 MB/s eta 0:00:07
#    ------------ --------------------------- 12.5/38.8 MB 4.3 MB/s eta 0:00:07
#    ------------- -------------------------- 12.7/38.8 MB 4.3 MB/s eta 0:00:07
#    ------------- -------------------------- 12.9/38.8 MB 4.3 MB/s eta 0:00:07
#    ------------- -------------------------- 13.1/38.8 MB 4.3 MB/s eta 0:00:07
#    ------------- -------------------------- 13.3/38.8 MB 4.3 MB/s eta 0:00:06
#    ------------- -------------------------- 13.5/38.8 MB 4.3 MB/s eta 0:00:06
#    -------------- ------------------------- 13.8/38.8 MB 4.3 MB/s eta 0:00:06
#    -------------- ------------------------- 14.0/38.8 MB 4.3 MB/s eta 0:00:06
#    -------------- ------------------------- 14.2/38.8 MB 4.3 MB/s eta 0:00:06
#    -------------- ------------------------- 14.4/38.8 MB 4.3 MB/s eta 0:00:06
#    --------------- ------------------------ 14.7/38.8 MB 4.3 MB/s eta 0:00:06
#    --------------- ------------------------ 14.9/38.8 MB 4.3 MB/s eta 0:00:06
#    --------------- ------------------------ 15.2/38.8 MB 4.3 MB/s eta 0:00:06
#    --------------- ------------------------ 15.4/38.8 MB 4.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 15.6/38.8 MB 4.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 15.8/38.8 MB 4.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.0/38.8 MB 4.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.3/38.8 MB 4.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.4/38.8 MB 4.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.5/38.8 MB 4.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.5/38.8 MB 4.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.5/38.8 MB 4.2 MB/s eta 0:00:06
#    ----------------- ---------------------- 16.5/38.8 MB 3.9 MB/s eta 0:00:06
#    ----------------- ---------------------- 16.6/38.8 MB 3.9 MB/s eta 0:00:06
#    ----------------- ---------------------- 16.6/38.8 MB 3.9 MB/s eta 0:00:06
#    ----------------- ---------------------- 16.9/38.8 MB 3.9 MB/s eta 0:00:06
#    ----------------- ---------------------- 17.1/38.8 MB 3.9 MB/s eta 0:00:06
#    ----------------- ---------------------- 17.3/38.8 MB 3.9 MB/s eta 0:00:06
#    ------------------ --------------------- 17.6/38.8 MB 3.9 MB/s eta 0:00:06
#    ------------------ --------------------- 17.7/38.8 MB 3.9 MB/s eta 0:00:06
#    ------------------ --------------------- 18.0/38.8 MB 3.9 MB/s eta 0:00:06
#    ------------------ --------------------- 18.2/38.8 MB 3.9 MB/s eta 0:00:06
#    ------------------ --------------------- 18.4/38.8 MB 3.9 MB/s eta 0:00:06
#    ------------------- -------------------- 18.6/38.8 MB 3.9 MB/s eta 0:00:06
#    ------------------- -------------------- 18.8/38.8 MB 3.9 MB/s eta 0:00:06
#    ------------------- -------------------- 19.0/38.8 MB 3.9 MB/s eta 0:00:06
#    ------------------- -------------------- 19.3/38.8 MB 3.9 MB/s eta 0:00:05
#    -------------------- ------------------- 19.5/38.8 MB 3.9 MB/s eta 0:00:05
#    -------------------- ------------------- 19.6/38.8 MB 3.9 MB/s eta 0:00:05
#    -------------------- ------------------- 19.8/38.8 MB 3.9 MB/s eta 0:00:05
#    -------------------- ------------------- 20.1/38.8 MB 3.9 MB/s eta 0:00:05
#    -------------------- ------------------- 20.3/38.8 MB 4.0 MB/s eta 0:00:05
#    --------------------- ------------------ 20.6/38.8 MB 4.0 MB/s eta 0:00:05
#    --------------------- ------------------ 20.8/38.8 MB 4.0 MB/s eta 0:00:05
#    --------------------- ------------------ 21.0/38.8 MB 4.0 MB/s eta 0:00:05
#    --------------------- ------------------ 21.2/38.8 MB 4.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 21.4/38.8 MB 4.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 21.6/38.8 MB 4.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 21.6/38.8 MB 4.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 21.9/38.8 MB 4.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.2/38.8 MB 4.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.4/38.8 MB 4.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.6/38.8 MB 4.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 22.8/38.8 MB 4.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 23.0/38.8 MB 4.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 23.3/38.8 MB 4.1 MB/s eta 0:00:04
#    ------------------------ --------------- 23.5/38.8 MB 4.1 MB/s eta 0:00:04
#    ------------------------ --------------- 23.7/38.8 MB 4.1 MB/s eta 0:00:04
#    ------------------------ --------------- 23.9/38.8 MB 4.1 MB/s eta 0:00:04
#    ------------------------ --------------- 24.1/38.8 MB 4.1 MB/s eta 0:00:04
#    ------------------------- -------------- 24.4/38.8 MB 4.1 MB/s eta 0:00:04
#    ------------------------- -------------- 24.6/38.8 MB 4.1 MB/s eta 0:00:04
#    ------------------------- -------------- 24.7/38.8 MB 4.1 MB/s eta 0:00:04
#    ------------------------- -------------- 24.9/38.8 MB 4.1 MB/s eta 0:00:04
#    ------------------------- -------------- 25.1/38.8 MB 4.1 MB/s eta 0:00:04
#    -------------------------- ------------- 25.4/38.8 MB 4.1 MB/s eta 0:00:04
#    -------------------------- ------------- 25.6/38.8 MB 4.1 MB/s eta 0:00:04
#    -------------------------- ------------- 25.9/38.8 MB 4.1 MB/s eta 0:00:04
#    -------------------------- ------------- 26.1/38.8 MB 4.1 MB/s eta 0:00:04
#    --------------------------- ------------ 26.3/38.8 MB 4.1 MB/s eta 0:00:04
#    --------------------------- ------------ 26.5/38.8 MB 4.1 MB/s eta 0:00:04
#    --------------------------- ------------ 26.8/38.8 MB 4.5 MB/s eta 0:00:03
#    --------------------------- ------------ 27.0/38.8 MB 4.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 27.2/38.8 MB 4.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 27.4/38.8 MB 4.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 27.6/38.8 MB 4.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 27.8/38.8 MB 4.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 27.9/38.8 MB 4.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 28.1/38.8 MB 4.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.3/38.8 MB 4.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.7/38.8 MB 4.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.8/38.8 MB 4.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 29.1/38.8 MB 4.5 MB/s eta 0:00:03
#    ------------------------------ --------- 29.2/38.8 MB 4.6 MB/s eta 0:00:03
#    ------------------------------ --------- 29.4/38.8 MB 4.5 MB/s eta 0:00:03
#    ------------------------------ --------- 29.6/38.8 MB 4.5 MB/s eta 0:00:03
#    ------------------------------ --------- 29.9/38.8 MB 4.5 MB/s eta 0:00:02
#    ------------------------------ --------- 30.1/38.8 MB 4.5 MB/s eta 0:00:02
#    ------------------------------- -------- 30.3/38.8 MB 4.5 MB/s eta 0:00:02
#    ------------------------------- -------- 30.5/38.8 MB 4.5 MB/s eta 0:00:02
#    ------------------------------- -------- 30.8/38.8 MB 4.5 MB/s eta 0:00:02
#    ------------------------------- -------- 31.0/38.8 MB 4.5 MB/s eta 0:00:02
#    -------------------------------- ------- 31.2/38.8 MB 4.5 MB/s eta 0:00:02
#    -------------------------------- ------- 31.4/38.8 MB 4.5 MB/s eta 0:00:02
#    -------------------------------- ------- 31.7/38.8 MB 4.5 MB/s eta 0:00:02
#    -------------------------------- ------- 31.9/38.8 MB 4.6 MB/s eta 0:00:02
#    --------------------------------- ------ 32.1/38.8 MB 4.6 MB/s eta 0:00:02
#    --------------------------------- ------ 32.4/38.8 MB 4.5 MB/s eta 0:00:02
#    --------------------------------- ------ 32.6/38.8 MB 4.6 MB/s eta 0:00:02
#    --------------------------------- ------ 32.7/38.8 MB 4.5 MB/s eta 0:00:02
#    --------------------------------- ------ 33.0/38.8 MB 4.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.2/38.8 MB 4.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.4/38.8 MB 4.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.6/38.8 MB 4.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.9/38.8 MB 4.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.0/38.8 MB 4.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.2/38.8 MB 4.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.5/38.8 MB 4.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.7/38.8 MB 4.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.9/38.8 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------ --- 35.1/38.8 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------ --- 35.5/38.8 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 35.7/38.8 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------ --- 35.9/38.8 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.1/38.8 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.3/38.8 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.6/38.8 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.7/38.8 MB 4.6 MB/s eta 0:00:01
#    -------------------------------------- - 37.0/38.8 MB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 37.3/38.8 MB 4.6 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.8 MB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 37.6/38.8 MB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 37.9/38.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.8 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.8 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.8 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.8 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  38.7/38.8 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 3.9 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)
# cache_dir indicates where to download data. I specified . which means current directory
# untar true will unzip it

# %%
data_dir
# Out:
# '.\\datasets\\flower_photos'

# %%
import pathlib
data_dir = pathlib.Path(data_dir)
data_dir
# Out:
# WindowsPath('datasets/flower_photos')

# %%
list(data_dir.glob('*/*.jpg'))[:5]
# Out:
# [WindowsPath('datasets/flower_photos/daisy/100080576_f52e8ee070_n.jpg'),
#  WindowsPath('datasets/flower_photos/daisy/10140303196_b88d3d6cec.jpg'),
#  WindowsPath('datasets/flower_photos/daisy/10172379554_b296050f82_n.jpg'),
#  WindowsPath('datasets/flower_photos/daisy/10172567486_2748826a8b.jpg'),
#  WindowsPath('datasets/flower_photos/daisy/10172636503_21bededa75_n.jpg')]

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
roses[:5]
# Out:
# [WindowsPath('datasets/flower_photos/roses/10090824183_d02c613f10_m.jpg'),
#  WindowsPath('datasets/flower_photos/roses/102501987_3cdb8e5394_n.jpg'),
#  WindowsPath('datasets/flower_photos/roses/10503217854_e66a804309.jpg'),
#  WindowsPath('datasets/flower_photos/roses/10894627425_ec76bbc757_n.jpg'),
#  WindowsPath('datasets/flower_photos/roses/110472418_87b6a3aa98_m.jpg')]

# %%
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>

# %%
tulips = list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x209>

# %%
flowers_images_dict = {
    'roses': list(data_dir.glob('roses/*')),
    'daisy': list(data_dir.glob('daisy/*')),
    'dandelion': list(data_dir.glob('dandelion/*')),
    'sunflowers': list(data_dir.glob('sunflowers/*')),
    'tulips': list(data_dir.glob('tulips/*')),
}

# %%
flowers_labels_dict = {
    'roses': 0,
    'daisy': 1,
    'dandelion': 2,
    'sunflowers': 3,
    'tulips': 4,
}

# %%
flowers_images_dict['roses'][:5]
# Out:
# [WindowsPath('datasets/flower_photos/roses/10090824183_d02c613f10_m.jpg'),
#  WindowsPath('datasets/flower_photos/roses/102501987_3cdb8e5394_n.jpg'),
#  WindowsPath('datasets/flower_photos/roses/10503217854_e66a804309.jpg'),
#  WindowsPath('datasets/flower_photos/roses/10894627425_ec76bbc757_n.jpg'),
#  WindowsPath('datasets/flower_photos/roses/110472418_87b6a3aa98_m.jpg')]

# %%
str(flowers_images_dict['roses'][0])
# Out:
# 'datasets\\flower_photos\\roses\\10090824183_d02c613f10_m.jpg'

# %%
img = cv2.imread(str(flowers_images_dict['roses'][0]))

# %%
img.shape
# Out:
# (240, 179, 3)

# %%
cv2.resize(img,(180,180)).shape
# Out:
# (180, 180, 3)

# %%
X, y = [], []

for flower_name, images in flowers_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(180,180))
        X.append(resized_img)
        y.append(flowers_labels_dict[flower_name])

# %%
X = np.array(X)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %%
num_classes = 5

model = Sequential([
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 26s 253ms/step - accuracy: 0.3779 - loss: 1.3982
# Epoch 2/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 260ms/step - accuracy: 0.6467 - loss: 0.9269
# Epoch 3/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - accuracy: 0.7051 - loss: 0.7637
# Epoch 4/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 256ms/step - accuracy: 0.8003 - loss: 0.5525
# Epoch 5/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.8946 - loss: 0.3327
# Epoch 6/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.9247 - loss: 0.2100
# Epoch 7/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.9710 - loss: 0.1103
# Epoch 8/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.9804 - loss: 0.0700
# Epoch 9/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - accuracy: 0.9796 - loss: 0.0636
# Epoch 10/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 21s 249ms/step - accuracy: 0.9749 - loss: 0.0835
# Epoch 11/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.9943 - loss: 0.0288
# Epoch 12/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 23s 266ms/step - accuracy: 0.9985 - loss: 0.0089
# Epoch 13/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.9993 - loss: 0.0051
# Epoch 14/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 15/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 257ms/step - accuracy: 0.9983 - loss: 0.0084
# Epoch 16/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.9999 - loss: 0.0019
# Epoch 17/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.9998 - loss: 0.0020
# Epoch 18/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - accuracy: 0.9990 - loss: 0.0075
# Epoch 19/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.9994 - loss: 0.0049
# Epoch 20/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.9990 - loss: 0.0053
# Epoch 21/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 1.0000 - loss: 7.3517e-04
# Epoch 22/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.9997 - loss: 0.0045
# Epoch 23/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.9448 - loss: 0.1809
# Epoch 24/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.9637 - loss: 0.1095
# Epoch 25/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 256ms/step - accuracy: 0.9753 - loss: 0.0697
# Epoch 26/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.9917 - loss: 0.0347
# Epoch 27/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.9954 - loss: 0.0248
# Epoch 28/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.9972 - loss: 0.0153
# Epoch 29/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.9999 - loss: 0.0015
# Epoch 30/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.9995 - loss: 0.0032

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6441 - loss: 2.3643
# [2.3634119033813477, 0.657952070236206]

# %%
predictions = model.predict(X_test_scaled)
predictions
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
# array([[ -3.7353866 ,  26.990843  ,  -0.09965312, -13.463124  ,
#          -7.5924826 ],
#        [ 16.257315  ,  -4.4626684 ,  -2.97181   ,  -7.508305  ,
#           2.7085347 ],
#        [ -7.8745847 ,  -1.0538245 ,  13.081899  , -11.594589  ,
#          -6.308649  ],
#        ...,
#        [ -2.2956913 , -14.761662  , -10.235531  ,   9.187838  ,
#           2.3031278 ],
#        [ -1.0370202 ,   2.1780262 ,  -2.5269685 ,  -4.4811053 ,
#          -1.7634876 ],
#        [ -6.9628167 , -19.9459    ,  -1.2987244 ,   6.365269  ,
#           1.497632  ]], dtype=float32)

# %%
score = tf.nn.softmax(predictions[0])
np.argmax(score)
# Out:
# 1

# %%
y_test[0]
# Out:
# 1

# %%
from tensorflow.keras.layers import RandomZoom, RandomFlip, RandomRotation

# %%
#Improve Accuracy through Data Augumentation
data_augmentation = keras.Sequential(
  [
    RandomFlip("horizontal",input_shape=(180,180,3)),
    RandomRotation(0.1),
    RandomZoom(0.1),
  ]
)
# Out:
# C:\Users\ntuse\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:18: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
plt.axis('off')
plt.imshow(X[0])

# %%
plt.axis('off')
plt.imshow(data_augmentation(X)[0].numpy().astype("uint8"))

# %%
num_classes = 5

model = Sequential([
  data_augmentation,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 37s 334ms/step - accuracy: 0.2661 - loss: 1.9226
# Epoch 2/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 325ms/step - accuracy: 0.4637 - loss: 1.2670
# Epoch 3/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 324ms/step - accuracy: 0.5875 - loss: 1.0478
# Epoch 4/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 323ms/step - accuracy: 0.6337 - loss: 0.9433
# Epoch 5/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 329ms/step - accuracy: 0.6486 - loss: 0.8669
# Epoch 6/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 324ms/step - accuracy: 0.6656 - loss: 0.8392
# Epoch 7/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 324ms/step - accuracy: 0.7028 - loss: 0.7795
# Epoch 8/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 328ms/step - accuracy: 0.6909 - loss: 0.7967
# Epoch 9/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 323ms/step - accuracy: 0.7177 - loss: 0.7344
# Epoch 10/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 323ms/step - accuracy: 0.7324 - loss: 0.6967
# Epoch 11/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 323ms/step - accuracy: 0.7321 - loss: 0.6928
# Epoch 12/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 322ms/step - accuracy: 0.7561 - loss: 0.6561
# Epoch 13/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 323ms/step - accuracy: 0.7682 - loss: 0.6286
# Epoch 14/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 324ms/step - accuracy: 0.7663 - loss: 0.5957
# Epoch 15/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 327ms/step - accuracy: 0.7600 - loss: 0.6077
# Epoch 16/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 328ms/step - accuracy: 0.7903 - loss: 0.5539
# Epoch 17/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 326ms/step - accuracy: 0.7787 - loss: 0.5557
# Epoch 18/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 324ms/step - accuracy: 0.7938 - loss: 0.5377
# Epoch 19/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 325ms/step - accuracy: 0.7987 - loss: 0.5283
# Epoch 20/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 322ms/step - accuracy: 0.8172 - loss: 0.4877
# Epoch 21/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 324ms/step - accuracy: 0.7909 - loss: 0.5375
# Epoch 22/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 323ms/step - accuracy: 0.8321 - loss: 0.4483
# Epoch 23/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 327ms/step - accuracy: 0.8203 - loss: 0.4819
# Epoch 24/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 326ms/step - accuracy: 0.8378 - loss: 0.4319
# Epoch 25/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 331ms/step - accuracy: 0.8438 - loss: 0.3963
# Epoch 26/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 325ms/step - accuracy: 0.8418 - loss: 0.4085
# Epoch 27/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 326ms/step - accuracy: 0.8642 - loss: 0.3649
# Epoch 28/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 328ms/step - accuracy: 0.8684 - loss: 0.3592
# Epoch 29/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 330ms/step - accuracy: 0.8631 - loss: 0.3552
# Epoch 30/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 28s 321ms/step - accuracy: 0.8706 - loss: 0.3539

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.7313 - loss: 0.8445
# [0.8247128129005432, 0.741830050945282]
